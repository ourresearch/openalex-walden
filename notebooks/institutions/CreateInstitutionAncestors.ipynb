# %% [markdown]
# # Create Institution Ancestors
#
# Computes institution ancestry (lineage) via recursive CTE.
#
# Uses:
# - `openalex.institutions.ror_relationships` - ROR relationships (from CreateRorDerivedTables)
# - `openalex.institutions.institutions` - Institution master table with ROR IDs
#
# Creates:
# - `openalex.institutions.institution_ancestors` - Lineage IDs for each institution
#
# Two kinds of ROR edge count as "ancestor":
# - `parent` - a child rolls up to its parent (the original behaviour)
# - `successor` - a predecessor rolls up to its successor (oxjob #1265). One-way, and only when the
#   predecessor has exactly one successor: mergers roll up (UPMC + Paris-Sorbonne -> Sorbonne Universite),
#   splits do not (IUPUI -> IU Indianapolis + Purdue Indianapolis would multiply-count). Successors never
#   inherit from predecessors. The role is visible to clients via `associated_institutions[].relationship`
#   (`successor` / `predecessor`), which CreateInstitutionsApi already emits.

# %%
# %sql
-- Create institution_ancestors table via recursive CTE
-- Walks up the hierarchy to build complete lineage.
--
-- Ancestor edges are ROR `parent` relationships PLUS single-successor `successor` relationships
-- (oxjob #1265): a predecessor rolls up to its one successor the way a child rolls up to its
-- parent. One-way only; predecessors with several successors (splits) are left alone so their
-- works are not multiply counted. ROR records succession asymmetrically (a `predecessor` row on
-- the successor's record is not always mirrored by a `successor` row on the predecessor's), so
-- both directions are unioned before the single-successor guard is applied.
CREATE OR REPLACE TABLE openalex.institutions.institution_ancestors AS
WITH RECURSIVE succession AS (
  SELECT ror_id AS predecessor_ror_id, related_ror_id AS successor_ror_id
  FROM openalex.institutions.ror_relationships
  WHERE relationship_type = 'successor'
  UNION
  SELECT related_ror_id AS predecessor_ror_id, ror_id AS successor_ror_id
  FROM openalex.institutions.ror_relationships
  WHERE relationship_type = 'predecessor'
),
single_successor AS (
  -- Guard: only predecessors with exactly one successor roll up
  SELECT predecessor_ror_id AS ror_id, MAX(successor_ror_id) AS related_ror_id
  FROM succession
  GROUP BY predecessor_ror_id
  HAVING COUNT(*) = 1
),
ancestor_edges AS (
  SELECT ror_id, related_ror_id, 'parent' AS edge_type
  FROM openalex.institutions.ror_relationships
  WHERE relationship_type = 'parent'
  UNION ALL
  SELECT ror_id, related_ror_id, 'successor' AS edge_type
  FROM single_successor
),
ancestorpath AS (
  -- Base case: direct parent / single-successor edges
  SELECT
    i.id AS institution_id,
    REPLACE(i.ror_id, 'https://ror.org/', '') AS ror_id,
    parent_i.id AS ancestor_id,
    e.related_ror_id AS ancestor_ror_id,
    1 AS generation,
    ARRAY(i.id) AS path
  FROM openalex.institutions.institutions i
  INNER JOIN ancestor_edges e
    ON REPLACE(i.ror_id, 'https://ror.org/', '') = e.ror_id
  INNER JOIN openalex.institutions.institutions parent_i
    ON e.related_ror_id = REPLACE(parent_i.ror_id, 'https://ror.org/', '')
  WHERE i.merge_into_id IS NULL
    AND parent_i.merge_into_id IS NULL

  UNION ALL

  -- Recursive case: grandparents, the parent's successor, the successor's parents, and beyond
  SELECT
    p.institution_id,
    p.ror_id,
    grandparent.id AS ancestor_id,
    e.related_ror_id AS ancestor_ror_id,
    p.generation + 1,
    ARRAY_UNION(p.path, ARRAY(grandparent.id))
  FROM ancestorpath p
  INNER JOIN ancestor_edges e
    ON p.ancestor_ror_id = e.ror_id
  INNER JOIN openalex.institutions.institutions grandparent
    ON e.related_ror_id = REPLACE(grandparent.ror_id, 'https://ror.org/', '')
  WHERE p.generation < 10  -- Prevent infinite loops
    AND NOT ARRAY_CONTAINS(p.path, grandparent.id)  -- Cycle detection
    AND grandparent.merge_into_id IS NULL
)
SELECT
  institution_id,
  ARRAY_DISTINCT(COLLECT_LIST(ancestor_id)) AS lineage_ids  -- multiple paths to one ancestor collapse to one entry
FROM ancestorpath
GROUP BY institution_id

# %%
# %sql
-- Verify: Count institutions with ancestors
SELECT 
  COUNT(*) as institutions_with_lineage,
  AVG(SIZE(lineage_ids)) as avg_lineage_depth,
  MAX(SIZE(lineage_ids)) as max_lineage_depth
FROM openalex.institutions.institution_ancestors

# %%
# %sql
-- Verification: Check UBC (I141945490) - should have NO ancestors after ROR fix
-- (UBC's "parent" relationships were changed to "related" in ROR)
SELECT * 
FROM openalex.institutions.institution_ancestors
WHERE institution_id = 141945490

# %%
# %sql
-- Sample: Show a few institutions with deep lineages
SELECT 
  ia.institution_id,
  i.display_name,
  SIZE(ia.lineage_ids) as lineage_depth,
  ia.lineage_ids
FROM openalex.institutions.institution_ancestors ia
JOIN openalex.institutions.institutions i ON ia.institution_id = i.id
ORDER BY SIZE(ia.lineage_ids) DESC
LIMIT 10

# %%
# %sql
-- Verification (#1265): merger rolls up one-way.
-- UPMC (4405264447) and Paris-Sorbonne (4405264515) should each list Sorbonne Universite (39804081);
-- Sorbonne Universite itself should have NO row (it has no parents and inherits nothing back).
SELECT i.id, i.display_name, ia.lineage_ids
FROM openalex.institutions.institutions i
LEFT JOIN openalex.institutions.institution_ancestors ia ON ia.institution_id = i.id
WHERE i.id IN (4405264447, 4405264515, 39804081)

# %%
# %sql
-- Verification (#1265): splits are NOT rolled up.
-- IUPUI (55769427) has two ROR successors; its lineage must stay its parents only (592451, 2801333002).
SELECT institution_id, lineage_ids
FROM openalex.institutions.institution_ancestors
WHERE institution_id = 55769427
