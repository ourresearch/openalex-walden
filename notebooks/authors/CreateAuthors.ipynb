-- %% [markdown]
-- ## Build `openalex_authors` by enriching `authors` with works data

-- %% [markdown]
-- #### Start from `authors`, enrich with work-level data from `openalex_works`

-- %%
%sql
CREATE OR REPLACE TABLE openalex.authors.author_works_staging
AS
WITH exploded_works AS (
  SELECT
    w.id,
    w.publication_year,
    w.publication_date,
    w.open_access,
    w.cited_by_count,
    w.topics,
    w.concepts,
    FILTER(
      TRANSFORM(w.locations, loc -> loc.source),
      s -> s.id IS NOT NULL
    ) AS work_sources,
    w.created_date,
    w.updated_date,
    a.author,
    a.raw_author_name,
    a.institutions,
    a.author_order_number,
    a.is_corresponding,
    CAST(REPLACE(a.author.id, 'https://openalex.org/A', '') AS BIGINT) AS author_id_num
  FROM openalex.works.openalex_works w
  LATERAL VIEW OUTER EXPLODE(w.authorships) AS a
  WHERE a.author.id IS NOT NULL
    AND a.author.id != 'https://openalex.org/A9999999999'
    AND a.author.id != 'https://openalex.org/A5317838346'
    AND a.author.id != 'https://openalex.org/A5098778687'
    AND a.author.id != 'https://openalex.org/A5040317105'
)
SELECT
  ew.id                                                    AS work_id,
  COALESCE(ew.publication_year, YEAR(ew.publication_date)) AS pub_year,
  CAST(ew.open_access.is_oa AS BOOLEAN)                    AS is_oa,
  CAST(ew.cited_by_count AS INT)                           AS work_cited_by_count,
  ew.topics                                                AS work_topics,
  ew.concepts                                              AS work_concepts,
  ew.work_sources                                          AS work_sources,
  ew.created_date                                          AS created_date,
  ew.updated_date                                          AS updated_date,
  CONCAT('https://openalex.org/A', CAST(ap.id AS STRING))  AS author_id,
  COALESCE(ew.author.display_name, ap.display_name)        AS author_display_name,
  ew.raw_author_name                                       AS raw_author_name,
  COALESCE(ew.institutions, ARRAY())                       AS author_institutions,
  ew.author_order_number                                   AS author_order_number,
  ew.is_corresponding                                      AS is_corresponding
FROM openalex.authors.authors ap
LEFT JOIN exploded_works ew ON ap.id = ew.author_id_num;

-- Improve locality & skipping for the GROUP BY
OPTIMIZE openalex.authors.author_works_staging
ZORDER BY (author_id, pub_year);

-- Optional but helpful for planning & data skipping
ANALYZE TABLE openalex.authors.author_works_staging COMPUTE STATISTICS;

-- %% [markdown]
-- #### Create `author_topics`

-- %%
%sql
CREATE OR REPLACE TABLE openalex.authors.author_topics CLUSTER BY (author_id) AS
WITH topics_and_share AS (
  WITH awt AS (
    -- explode once; distinct by (author, work, topic)
    SELECT DISTINCT
      author_id,
      work_id,
      CAST(t.id AS STRING) AS topic_id,
      t.display_name, t.subfield, t.field, t.domain, t.score
    FROM (
      SELECT author_id, work_id, EXPLODE_OUTER(work_topics) AS t
      FROM openalex.authors.author_works_staging
      WHERE work_id IS NOT NULL
    )
    WHERE t.id IS NOT NULL
  ),
  counts AS (
    -- author-topic counts AND topic totals in one pass
    SELECT
      author_id,                 -- NULL on total rows
      topic_id,
      MAX_BY(display_name, score) AS display_name,
      MAX_BY(subfield,     score) AS subfield,
      MAX_BY(field,        score) AS field,
      MAX_BY(domain,       score) AS domain,
      COUNT(DISTINCT work_id)    AS cnt
    FROM awt
    GROUP BY GROUPING SETS (
      (author_id, topic_id),
      (topic_id)
    )
  ),
  with_totals AS (
    -- compute topic_total via window BEFORE filtering author rows
    SELECT
      author_id,
      topic_id,
      display_name, subfield, field, domain,
      cnt AS topic_count,
      MAX(CASE WHEN author_id IS NULL THEN cnt END)
        OVER (PARTITION BY topic_id) AS topic_total
    FROM counts
  )
  -- final: include ALL topics; round share to 7 decimals; sort arrays
  SELECT
    author_id,
    ARRAY_SORT(
      COLLECT_LIST(
        STRUCT(
          topic_id AS id,
          display_name,
          CAST(topic_count AS INT) AS count,
          subfield,
          field,
          domain
        )
      ),
      (l, r) -> CASE WHEN l.count > r.count THEN -1 WHEN l.count < r.count THEN 1 WHEN l.id < r.id THEN -1 WHEN l.id > r.id THEN 1 ELSE 0 END
    ) AS topics,
    ARRAY_SORT(
      COLLECT_LIST(
        STRUCT(
          topic_id AS id,
          display_name,
          ROUND(CAST(topic_count AS DOUBLE) / NULLIF(topic_total, 0), 7) AS value,
          subfield,
          field,
          domain
        )
      ),
      (l, r) -> CASE WHEN l.value > r.value THEN -1 WHEN l.value < r.value THEN 1 WHEN l.id < r.id THEN -1 WHEN l.id > r.id THEN 1 ELSE 0 END
    ) AS topic_share
  FROM with_totals
  WHERE author_id IS NOT NULL
  GROUP BY author_id
)
SELECT * FROM topics_and_share;

OPTIMIZE openalex.authors.author_topics FULL;

-- %%
%sql
-- Snapshot current hashes before rebuild
CREATE OR REPLACE TABLE openalex.authors.openalex_authors_hash AS
SELECT id, updated_date,
  xxhash64(CONCAT_WS('|',
    CAST(id AS STRING),
    COALESCE(display_name, ''),
    COALESCE(full_name, ''),
    COALESCE(TO_JSON(raw_author_names), '[]'),
    COALESCE(orcid, ''),
    -- observed_orcids + ids are rebuilt here from parts so the pre-rebuild snapshot hashes like the
    -- post-rebuild row (cell 9): rows from before #1267 (NULL array, ids without the key) hash as
    -- observed_orcids = [orcid], which is what the rebuild produces when nothing else is observed.
    COALESCE(TO_JSON(COALESCE(observed_orcids, ARRAY_COMPACT(ARRAY(orcid)))), '[]'),
    COALESCE(TO_JSON(NAMED_STRUCT(
      'openalex', ids.openalex,
      'orcid', ids.orcid,
      'observed_orcids', COALESCE(observed_orcids, ARRAY_COMPACT(ARRAY(orcid)))
    )), '{}'),
    COALESCE(CAST(works_count AS STRING), '0'),
    COALESCE(CAST(cited_by_count AS STRING), '0'),
    COALESCE(TO_JSON(summary_stats), '{}'),
    COALESCE(TO_JSON(affiliations), '[]'),
    COALESCE(TO_JSON(last_known_institutions), '[]'),
    COALESCE(TO_JSON(sources), '[]'),
    COALESCE(TO_JSON(counts_by_year), '[]'),
    COALESCE(TO_JSON(topics), '[]'),
    -- topic_share excluded (non-deterministic: depends on global corpus)
    COALESCE(TO_JSON(x_concepts), '[]')
  )) AS content_hash
FROM openalex.authors.openalex_authors;

-- %% [markdown]
-- ### Create Final table `openalex.authors.openalex_authors`

-- %%
%sql
-- Guardrail: Abort if staging table is empty or drastically smaller than current
-- This prevents a cascading failure where empty openalex_authors causes NULL author.ids
-- in openalex_works, which then causes author_works_staging to be empty on the next run.

DECLARE OR REPLACE VARIABLE staging_count BIGINT;
DECLARE OR REPLACE VARIABLE current_count BIGINT;

SET VARIABLE staging_count = (SELECT COUNT(DISTINCT author_id) FROM openalex.authors.author_works_staging);
SET VARIABLE current_count = (SELECT COUNT(*) FROM openalex.authors.openalex_authors);

SELECT 
  staging_count AS staging_unique_authors,
  current_count AS current_authors,
  ROUND(staging_count * 100.0 / NULLIF(current_count, 0), 2) AS pct_of_current;

-- Fail if staging is empty
SELECT CASE 
  WHEN staging_count = 0 
  THEN RAISE_ERROR('GUARDRAIL FAILED: author_works_staging has 0 unique authors. This would create an empty openalex_authors table and cause a cascading failure.')
END;

-- Fail if staging has less than 90% of current (allows for some legitimate churn)
SELECT CASE 
  WHEN current_count > 0 AND staging_count < current_count * 0.9 
  THEN RAISE_ERROR(CONCAT('GUARDRAIL FAILED: staging has only ', CAST(ROUND(staging_count * 100.0 / current_count, 1) AS STRING), '% of current authors (', CAST(staging_count AS STRING), ' vs ', CAST(current_count AS STRING), '). This may indicate corrupted source data.'))
END;

-- %%
%sql
CREATE OR REPLACE TABLE openalex.authors.openalex_authors
CLUSTER BY (id, updated_date) AS
WITH 
-- concepts (group by concept.id only, use MAX for score to ensure determinism)
author_concepts_exploded AS (
  SELECT
    author_id,
    concept.id AS concept_id,
    ANY_VALUE(concept.wikidata) AS wikidata,
    ANY_VALUE(concept.display_name) AS display_name,
    ANY_VALUE(concept.level) AS level,
    MAX(concept.score) AS score,
    COUNT(*) AS concept_count
  FROM openalex.authors.author_works_staging
  LATERAL VIEW OUTER EXPLODE(work_concepts) t AS concept
  WHERE concept.id IS NOT NULL
  GROUP BY author_id, concept.id
  QUALIFY ROW_NUMBER() OVER (
    PARTITION BY author_id
    ORDER BY concept_count DESC, CAST(concept_id AS STRING) ASC
  ) <= 5
),
concepts_packed AS (
  SELECT
    author_id,
    ARRAY_SORT(
      COLLECT_LIST(
        STRUCT(
          concept_id AS id,
          wikidata,
          display_name,
          CAST(level AS INT),
          score,
          CAST(concept_count AS INT) AS count
        )
      ),
      (l, r) -> CASE WHEN l.score > r.score THEN -1 WHEN l.score < r.score THEN 1 WHEN l.id < r.id THEN -1 WHEN l.id > r.id THEN 1 ELSE 0 END
    ) AS x_concepts
  FROM author_concepts_exploded
  GROUP BY author_id
),

-- affiliations
affiliations_exploded AS (
  SELECT
    author_id,
    i.id                             AS inst_id,
    ANY_VALUE(i.ror)                 AS ror,
    ANY_VALUE(i.display_name)        AS display_name,
    ANY_VALUE(i.country_code)        AS country_code,
    ANY_VALUE(i.type)                AS type,
    ANY_VALUE(i.lineage)             AS lineage,
    SORT_ARRAY(COLLECT_SET(pub_year), false) AS years
  FROM (
    SELECT author_id, pub_year, EXPLODE_OUTER(author_institutions) AS i
    FROM openalex.authors.author_works_staging
    WHERE pub_year IS NOT NULL
  )
  WHERE i.id IS NOT NULL
  GROUP BY author_id, i.id
),
affiliations_packed AS (
  SELECT
    author_id,
    ARRAY_SORT(
      COLLECT_LIST(
        STRUCT(
          STRUCT(inst_id as id, ror, display_name, country_code, type, lineage) as institution,
          years
        )
      ),
      (l, r) -> CASE WHEN l.institution.id < r.institution.id THEN -1 WHEN l.institution.id > r.institution.id THEN 1 ELSE 0 END
    ) AS affiliations
  FROM affiliations_exploded
  GROUP BY author_id
),
sources_agg AS (
  SELECT
    author_id,
    -- COLLECT_SET deduplicates the struct objects
    ARRAY_SORT(COLLECT_SET(src), (l, r) -> CASE WHEN l.id < r.id THEN -1 WHEN l.id > r.id THEN 1 ELSE 0 END) AS sources
  FROM (
    SELECT author_id, EXPLODE(work_sources) AS src
    FROM openalex.authors.author_works_staging
    WHERE work_sources IS NOT NULL
  ) t
  WHERE src.id IS NOT NULL
  GROUP BY author_id
),

-- counts
counts_per_year AS (
  SELECT
    author_id,
    CAST(pub_year AS INT) AS year,
    CAST(count(*) AS INT) AS works_count,
    CAST(sum(if(is_oa, 1, 0)) AS INT) AS oa_works_count,
    CAST(sum(work_cited_by_count) AS INT) AS cited_by_count
  FROM openalex.authors.author_works_staging
  WHERE pub_year IS NOT NULL
  GROUP BY author_id, pub_year
),
counts_agg AS (
  SELECT
    author_id,
    SORT_ARRAY(
      COLLECT_LIST(
        STRUCT(
          year,
          works_count,
          oa_works_count,
          cited_by_count
        )
      ),
      true
    ) as counts_by_year
  FROM counts_per_year
  GROUP BY author_id
),

-- last known institutions
last_inst_agg AS (
  SELECT
    wa.author_id,
    ARRAY_SORT(COLLECT_SET(STRUCT(i.id, i.ror, i.display_name, i.country_code, i.type, i.lineage)), (l, r) -> CASE WHEN l.id < r.id THEN -1 WHEN l.id > r.id THEN 1 ELSE 0 END) as last_known_institutions
  FROM openalex.authors.author_works_staging wa
  INNER JOIN (
      SELECT author_id, MAX(pub_year) as max_year 
      FROM openalex.authors.author_works_staging
      GROUP BY author_id
  ) my ON wa.author_id = my.author_id AND wa.pub_year = my.max_year
  LATERAL VIEW OUTER EXPLODE(author_institutions) t AS i
  WHERE i.id IS NOT NULL
  GROUP BY wa.author_id
),

-- main aggregation
main_agg_pre AS (
  SELECT
    CAST(REPLACE(b.author_id, 'https://openalex.org/A', '') AS BIGINT) AS id,
    b.author_id AS author_id_str,
    SLICE(
      ARRAY_SORT(
        ARRAY_DISTINCT(
          ARRAY_COMPACT(
            CONCAT(COLLECT_LIST(b.author_display_name), COLLECT_LIST(b.raw_author_name))
          )
        )
      ),
      1, 100
    ) AS raw_author_names,
    CAST(COUNT(work_id) AS INT) AS works_count,
    COALESCE(CAST(SUM(work_cited_by_count) AS INT), 0) AS cited_by_count,
    COUNT_IF(is_oa) AS oa_works_count,
    CAST(AVG(CASE WHEN b.pub_year >= YEAR(current_date()) - 2 THEN work_cited_by_count END) AS DOUBLE) AS two_year_mean,
    CAST(COUNT_IF(work_cited_by_count >= 10) AS INT) AS i10_index,
    SORT_ARRAY(
      TRANSFORM(
        FILTER(COLLECT_LIST(work_cited_by_count), x -> x IS NOT NULL),
        x -> CAST(x AS INT)
      ),
      false
    ) AS sorted_citations,
    MAX(b.pub_year) AS max_pub_year,
    CONCAT('https://api.openalex.org/works?filter=author.id:',
           REGEXP_EXTRACT(b.author_id, '/(A[0-9]+)$', 1)) AS works_api_url,
    CAST(NULL AS TIMESTAMP) AS updated_date,
    DATE_TRUNC('SECOND', CAST(MIN(b.created_date) AS TIMESTAMP)) AS created_date
  FROM openalex.authors.author_works_staging b
  GROUP BY b.author_id
),

-- trusted seat ORCIDs per profile (CreateAuthorObservedOrcids), minus a curated removal (#1267)
observed_pre AS (
  SELECT m.id,
    FILTER(COALESCE(oo.seat_orcids, ARRAY()), x -> NOT (x.orcid <=> NULLIF(oc.removed_orcid, ''))) AS seat_orcids_kept
  FROM main_agg_pre m
  LEFT JOIN openalex.authors.author_observed_orcids oo ON m.id = oo.author_id
  LEFT JOIN openalex.authors.author_orcid_curations oc ON m.id = oc.author_id
),

-- served name (oxjob #1297): serve the matching name (authors.full_name) instead of the mint-time display_name
-- when it is attested on the profile's own works under the nightly UpdateAuthorFullNames evidence rules
-- (>= 2 seats and is_clean: natural order, no digits/commas/credentials/doubled tokens) and either
--   (a) the two names disagree on the person's block (different surname or first initial) and full_name is at
--       least as well attested as display_name -- the PubMed 'Lastname Xy' junk displays that pollution_reset fixed; or
--   (b) full_name is a strict refinement of display_name: first initial -> word, middle appears or initial -> word,
--       nothing degrades (mirrors the enrich gain rule).
-- Otherwise the mint-time display_name stands. Catalog-order and other unclean legacy full_names (~8% of profiles)
-- are never served; a curation always wins (enriched_agg). Measured 2026-09-21: 1.67M of 128M active profiles change.
served_name AS (
  SELECT id,
    CASE WHEN f_n >= 2 AND f_clean AND f_last IS NOT NULL AND COALESCE(f_first, '') <> ''
          AND (
            (diff_block AND f_n >= COALESCE(d_n, 0))
            OR (NOT diff_block
                AND NOT (dfl = ffl AND dml = fml)
                AND (dfl = ffl OR (LENGTH(dfl) <= 1 AND LENGTH(ffl) >= 2))
                AND (dml = fml OR dml = '' OR (LENGTH(dml) = 1 AND SUBSTRING(fml, 1, 1) = dml)))
          )
         THEN full_name END AS served_name
  FROM (
    SELECT ar.id, TRIM(ar.full_name) AS full_name,
      fn.parsed_name.first AS f_first, fn.parsed_name.last AS f_last,
      fe.n AS f_n, fe.is_clean AS f_clean, de.n AS d_n,
      (dn.parsed_name.last IS NULL OR dn.parsed_name.last <> fn.parsed_name.last
       OR SUBSTRING(dn.parsed_name.first, 1, 1) <> SUBSTRING(fn.parsed_name.first, 1, 1)) AS diff_block,
      REGEXP_REPLACE(COALESCE(dn.parsed_name.first, ''),  '[^\\p{L}]', '') AS dfl,
      REGEXP_REPLACE(COALESCE(fn.parsed_name.first, ''),  '[^\\p{L}]', '') AS ffl,
      REGEXP_REPLACE(COALESCE(dn.parsed_name.middle, ''), '[^\\p{L}]', '') AS dml,
      REGEXP_REPLACE(COALESCE(fn.parsed_name.middle, ''), '[^\\p{L}]', '') AS fml
    FROM openalex.authors.authors ar
    LEFT JOIN openalex.authors.author_names fn ON TRIM(ar.full_name) = fn.raw_author_name
    LEFT JOIN openalex.authors.author_names dn ON TRIM(ar.display_name) = dn.raw_author_name
    LEFT JOIN openalex.authors.author_full_name_evidence fe
      ON fe.author_id = ar.id AND fe.raw = TRIM(ar.full_name) AND fe.n IS NOT NULL
    LEFT JOIN openalex.authors.author_full_name_evidence de
      ON de.author_id = ar.id AND de.raw = TRIM(ar.display_name) AND de.n IS NOT NULL
    WHERE ar.full_name IS NOT NULL AND TRIM(ar.full_name) <> ''
      AND TRIM(ar.full_name) IS DISTINCT FROM TRIM(ar.display_name)
  )
),

-- join authors for identity fields; apply display_name curation override, then the served-name rule (#1297)
enriched_agg AS (
  SELECT
    m.*,
    COALESCE(NULLIF(c.curated_display_name, ''), sn.served_name, ar.display_name) AS display_name,
    -- primary ORCID (#1267): curated > most trusted seats > legacy mint-time value (authors.orcid, never recomputed).
    -- The legacy value is kept only while the profile has works: an emptied duplicate must not hold a person's
    -- ORCID forever (77,613 zero-works profiles did on 2026-09-23; these profiles are slated for deletion).
    CASE
      WHEN oc.curated_orcid IS NOT NULL AND oc.curated_orcid <> '' THEN oc.curated_orcid  -- replace: set correct ORCID (#410)
      WHEN SIZE(op.seat_orcids_kept) > 0 THEN op.seat_orcids_kept[0].orcid                -- organic: the trusted seat ORCID with the most seats
      WHEN oc.removed_orcid IS NOT NULL AND ar.orcid = oc.removed_orcid THEN NULL          -- remove: detach wrong ORCID, this author only
      WHEN m.works_count > 0 THEN ar.orcid                                                 -- no trusted seat evidence either way: keep the mint-time value
      ELSE NULL                                                                            -- zero works: nothing supports the legacy value, drop it
    END AS orcid,
    op.seat_orcids_kept,
    ar.full_name,
    named_struct(
      '2yr_mean_citedness', COALESCE(two_year_mean, 0),
      'h_index',
        COALESCE(
          CAST(
            ARRAY_MAX(
              ZIP_WITH(
                sorted_citations,
                SEQUENCE(1, SIZE(sorted_citations)),
                (citation, rank) -> IF(citation >= rank, rank, 0)
              )
            ) AS INT
          ), 0),
      'i10_index', COALESCE(i10_index,0)
    ) AS summary_stats
  FROM main_agg_pre m
  LEFT JOIN openalex.authors.authors ar ON m.id = ar.id
  LEFT JOIN openalex.authors.author_names_curations c ON m.id = c.author_id
  LEFT JOIN openalex.authors.author_orcid_curations oc ON m.id = oc.author_id
  LEFT JOIN observed_pre op ON m.id = op.id
  LEFT JOIN served_name sn ON m.id = sn.id
)

-- final select
SELECT
  m.id,
  m.display_name,
  m.raw_author_names,
  m.orcid,
  -- every trusted ORCID on the profile's seats, primary first (#1267); [] when none
  ARRAY_COMPACT(ARRAY_DISTINCT(CONCAT(ARRAY(m.orcid), TRANSFORM(m.seat_orcids_kept, x -> x.orcid)))) AS observed_orcids,
  m.full_name,
  -- block_key derived from full_name via author_names
  CASE
    WHEN pn_bk.parsed_name.last IS NULL THEN NULL
    WHEN pn_bk.parsed_name.first IS NULL OR pn_bk.parsed_name.first = '' THEN pn_bk.parsed_name.last
    ELSE CONCAT(SUBSTRING(pn_bk.parsed_name.first, 1, 1), ' ', pn_bk.parsed_name.last)
  END AS block_key,
  m.works_count,
  m.cited_by_count,
  m.summary_stats,
  named_struct(
    'openalex', m.author_id_str,
    'orcid', m.orcid,
    'observed_orcids', ARRAY_COMPACT(ARRAY_DISTINCT(CONCAT(ARRAY(m.orcid), TRANSFORM(m.seat_orcids_kept, x -> x.orcid))))
  ) AS ids,
  COALESCE(ap.affiliations, ARRAY()) AS affiliations,
  la.last_known_institutions,
  COALESCE(at.topics, ARRAY()) AS topics,
  COALESCE(at.topic_share, ARRAY()) AS topic_share,
  COALESCE(cp.x_concepts, ARRAY()) AS x_concepts,
  COALESCE(s.sources, ARRAY()) AS sources,
  cby.counts_by_year,
  m.works_api_url,
  m.updated_date,
  m.created_date
FROM enriched_agg m
LEFT JOIN openalex.authors.author_topics at ON m.author_id_str = at.author_id
LEFT JOIN concepts_packed cp ON m.author_id_str = cp.author_id
LEFT JOIN affiliations_packed ap ON m.author_id_str = ap.author_id
LEFT JOIN sources_agg s ON m.author_id_str = s.author_id
LEFT JOIN counts_agg cby ON m.author_id_str = cby.author_id
LEFT JOIN last_inst_agg la ON m.author_id_str = la.author_id
LEFT JOIN openalex.authors.author_names pn_bk ON TRIM(m.full_name) = pn_bk.raw_author_name;

-- %%
%sql
-- Compare hashes and set updated_date only when content changed
WITH new_hashes AS (
  SELECT id,
    xxhash64(CONCAT_WS('|',
      CAST(id AS STRING),
      COALESCE(display_name, ''),
      COALESCE(full_name, ''),
      COALESCE(TO_JSON(raw_author_names), '[]'),
      COALESCE(orcid, ''),
      COALESCE(TO_JSON(observed_orcids), '[]'),
      COALESCE(TO_JSON(ids), '{}'),
      COALESCE(CAST(works_count AS STRING), '0'),
      COALESCE(CAST(cited_by_count AS STRING), '0'),
      COALESCE(TO_JSON(summary_stats), '{}'),
      COALESCE(TO_JSON(affiliations), '[]'),
      COALESCE(TO_JSON(last_known_institutions), '[]'),
      COALESCE(TO_JSON(sources), '[]'),
      COALESCE(TO_JSON(counts_by_year), '[]'),
      COALESCE(TO_JSON(topics), '[]'),
      -- topic_share excluded (non-deterministic: depends on global corpus)
      COALESCE(TO_JSON(x_concepts), '[]')
    )) AS content_hash
  FROM openalex.authors.openalex_authors
)
MERGE INTO openalex.authors.openalex_authors AS target
USING (
  SELECT n.id,
    CASE
      WHEN p.id IS NULL THEN DATE_TRUNC('SECOND', CURRENT_TIMESTAMP())
      WHEN n.content_hash <> p.content_hash THEN DATE_TRUNC('SECOND', CURRENT_TIMESTAMP())
      ELSE p.updated_date
    END AS new_updated_date
  FROM new_hashes n
  LEFT JOIN openalex.authors.openalex_authors_hash p ON n.id = p.id
) AS source
ON target.id = source.id
WHEN MATCHED THEN UPDATE SET target.updated_date = source.new_updated_date;

-- %%
-- Compact files after MERGE so liquid clustering on (id, updated_date)
-- organizes files by updated_date. This enables data skipping for
-- downstream jobs that filter on updated_date (snapshot export, ES sync).
OPTIMIZE openalex.authors.openalex_authors;

-- %% [markdown]
-- ### Create mapping table for AND

-- %%
%sql
CREATE OR REPLACE TABLE openalex.authors.authors_for_matching
CLUSTER BY (block_key)
AS
SELECT
  -- 1. Blocking Key: the profile-level canonical parse (oxjob #1360) when the profile has one, else the full_name parse
  COALESCE(cn.block_key, oa.block_key) AS block_key,

  -- 2. Candidate Identity
  oa.id AS author_id,
  oa.display_name,
  oa.full_name,
  oa.ids.orcid as orcid,
  oa.observed_orcids,  -- every trusted ORCID on the profile; MatchAuthors' ORCID tier explodes this (#1267)

  -- 3. Parsed name columns for matching in MatchAuthors: canonical (voted over every attested string, oxjob #1360) else full_name's
  COALESCE(cn.first_norm, pn.parsed_name.first) AS first,
  SUBSTRING(COALESCE(cn.first_norm, pn.parsed_name.first), 1, 1) AS first_initial,
  COALESCE(cn.middle_norm, pn.parsed_name.middle) AS middle,
  COALESCE(cn.last_norm, pn.parsed_name.last) AS last,
  -- alternate readings (oxjob #1341 generator + the canonical family_tokens, oxjob #1360)
  COALESCE(cn.alt_parses, pn.alt_parses) AS alt_parses,
  COALESCE(TRANSFORM(cn.alt_parses, x -> x.key), pn.alt_block_keys) AS alt_block_keys,
  cn.confidence AS parse_confidence,
  cn.order_source AS parse_order_source,
  cn.parse_version AS parse_version,

  ARRAY_DISTINCT(
     TRANSFORM(
       FILTER(oa.affiliations, x -> x.institution.id IS NOT NULL),
       x -> x.institution.id
     )
  ) AS institution_ids,
  
  ARRAY_DISTINCT(
     TRANSFORM(oa.topics, x -> x.id)
  ) AS topic_ids,

  array_distinct(
    TRANSFORM(oa.topics, x -> x.subfield.id)
  ) AS subfield_ids,

  TRANSFORM(oa.sources, x -> x.id) AS source_ids,

  ARRAY_DISTINCT(
    TRANSFORM(
        ARRAY_UNION(ARRAY(oa.display_name), COALESCE(oa.raw_author_names, ARRAY())),
        n -> LOWER(TRIM(n))
    )
  ) AS name_variants,

  oa.works_count,
  oa.cited_by_count,
  COALESCE(oa.summary_stats.h_index, 0) AS h_index,
  
  CAST(ARRAY_MIN(TRANSFORM(oa.counts_by_year, x -> x.year)) AS INT) AS first_active_year,
  CAST(ARRAY_MAX(TRANSFORM(oa.counts_by_year, x -> x.year)) AS INT) AS last_active_year

FROM openalex.authors.openalex_authors oa
LEFT JOIN openalex.authors.author_names pn ON TRIM(oa.full_name) = pn.raw_author_name
LEFT JOIN openalex.authors.author_canonical_names cn
  ON cn.author_id = oa.id AND cn.kind = 'person' AND cn.block_key IS NOT NULL AND cn.block_key <> ''
WHERE COALESCE(cn.block_key, oa.block_key) IS NOT NULL
  -- Exclude zero-works profiles from the match candidate pool. Drains the merged-loser tail:
  -- profiles whose work_authors rows have all been rewritten to a winner_author_id by any
  -- author_merge_log_* MERGE step show works_count = 0 here on the next CreateAuthors
  -- refresh, so this filter prevents MatchAuthors from re-attaching new daily-ingest works
  -- to drained losers (race-tail problem observed at 24h Phase 4 drain).
  -- Also drops ~3M legacy zero-works profiles (junk metadata, non-person entities,
  -- abandoned MAG/Crossref records) that have no business being match candidates.
  -- Match-candidate pool: 117.7M -> ~116.4M (-3.2%, all zero-signal profiles).
  AND oa.works_count > 0;

OPTIMIZE openalex.authors.authors_for_matching;

-- oxjob #1341: one row per (profile, key) over the primary block key plus every alternate key.
-- MatchAuthors joins a seat's keys (primary + alternates) against this table to reach profiles that
-- sit in another primary block (compound surnames, reversed order, transliteration variants).
-- Alternate keys never extend into mega blocks: an alternate entry is kept only when fewer than
-- 10K profiles carry that key; primary entries are always kept. Served names never read this.
CREATE OR REPLACE TABLE openalex.authors.authors_for_matching_keys
CLUSTER BY (key)
AS
WITH all_keys AS (
  SELECT author_id, block_key AS key, TRUE AS is_primary, first, last, first AS p_first, last AS p_last
  FROM openalex.authors.authors_for_matching
  WHERE block_key IS NOT NULL AND block_key != ''
  UNION ALL
  -- p_first/p_last = the profile's primary parse, so MatchAuthors can classify the reading (oxjob #1341)
  SELECT author_id, p.key, FALSE AS is_primary, p.first, p.last, first AS p_first, last AS p_last
  FROM openalex.authors.authors_for_matching
  LATERAL VIEW explode(COALESCE(alt_parses, ARRAY())) AS p
),
dedup AS (
  -- one row per (profile, key); a primary entry wins over an alternate with the same key
  SELECT author_id, key, MAX(is_primary) AS is_primary,
         MAX_BY(first, is_primary) AS first, MAX_BY(last, is_primary) AS last, MAX(p_first) AS p_first, MAX(p_last) AS p_last
  FROM all_keys GROUP BY author_id, key
),
sizes AS (
  SELECT key, COUNT(*) AS block_size FROM dedup GROUP BY key
)
SELECT d.author_id, d.key, d.is_primary, d.first, d.last, d.p_first, d.p_last, CAST(s.block_size AS INT) AS block_size
FROM dedup d
JOIN sizes s ON s.key = d.key
WHERE d.is_primary OR s.block_size <= 10000;

OPTIMIZE openalex.authors.authors_for_matching_keys;
