# %%
# %run ./_utils

# %%
import json
from datetime import datetime
from pyspark.sql import functions as F

# %% [markdown]
# #### Create `openalex.common.openalex_keywords_snapshot` in same format as API

# %%
df_transformed = (
    spark.read.table("openalex.common.keywords_api")
    # No ID transformation needed - already full URLs
)

df_transformed.write \
    .mode("overwrite") \
    .option("overwriteSchema", "true") \
    .saveAsTable("openalex.common.openalex_keywords_snapshot")

# %% [markdown]
# #### Export to JSONL + Parquet on S3
# Writes both formats under `s3://openalex-snapshots/full/{date}/{format}/keywords/`.

# %%
date_str = get_snapshot_date()
df = spark.read.table("openalex.common.openalex_keywords_snapshot")
export_partitioned_all_formats(spark, dbutils, df, date_str, "keywords", salt=False)
