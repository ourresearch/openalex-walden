-- %% [markdown]
-- ### Creates `openalex.works.locations_w_sources` in Walden End to End workflow

-- %%
-- Materialize superlocations into a staging table clustered by provenance.
-- This avoids 4x re-evaluation of the CTE that reads superlocations (Spark SQL
-- re-scans the base table for each CTE reference). Clustering by provenance
-- enables data skipping so each provenance-filtered read only touches ~25% of files.
CREATE OR REPLACE TABLE identifier('openalex' || :env_suffix || '.works._lws_staging')
CLUSTER BY (provenance)
AS SELECT * FROM identifier('openalex' || :env_suffix || '.works.superlocations');

-- %%
CREATE OR REPLACE TABLE identifier('openalex' || :env_suffix || '.works.locations_w_sources')
CLUSTER BY (best_doi, provenance, native_id)
TBLPROPERTIES (
  'delta.dataSkippingNumIndexedCols' = 40,
  'delta.deletedFileRetentionDuration' = '30 days',
  'delta.logRetentionDuration' = '30 days'
)
AS (
WITH
sources_filtered AS (
  SELECT *
  FROM openalex.sources.sources
  WHERE merge_into_id IS NULL
    AND id IS NOT NULL
    AND id NOT IN (
      4377196106, -- Internet Archive (Internet Archive)
      4306400349, -- CiteSeer X (The Pennsylvania State University)
      4308707206, -- Library Union Catalog of Bavaria, Berlin and Brandenburg (B3Kat Repository)
      4377196246, -- CISION
      4306400063, -- Scopus (Elsevier)
      7407052528, -- ResearchGate
      4306402117, -- Portail des Bibliotheques Municipales Specialisees (City of Paris)
      7407051242, -- E-Pics Bildarchiv
      7407051288, -- WSL Landesforstinventar
      4306400108  -- Library Stack (Library Stack)
    )
),
sources_intermediate as (
  select
    id,
    explode(issns) as issn,
    endpoint_id,
    sample_pmh_record,
    merge_into_id,
    is_oa as is_oa_source
  from
    sources_filtered
),
existing_sources_for_other_works as (
  select
    id,
    row_number() over (partition by issn order by id asc) as id_row_number,
    issn,
    is_oa_source,
    endpoint_id as endpoint_id_sources,
    sample_pmh_record,
    split_part(sample_pmh_record, ":", 2) as pmh_record_matching_string
  from
    sources_intermediate
),
existing_sources_for_repos as (
  select
    s.id,
    e.endpoint_id,
    s.is_oa as is_oa_source,
    row_number() over (
        partition by e.endpoint_id
        order by s.id asc
      ) as repo_row_number
  from
    openalex.sources.endpoint_to_source e
    join sources_filtered s on e.source_id = s.id
),
existing_sources_for_datacite as (
  select
    id,
    exploded_datacite_id as datacite_id,
    is_oa as is_oa_source,
    row_number() over (partition by exploded_datacite_id order by id asc) as datacite_row_number
  from
    sources_filtered
    lateral view explode(datacite_ids) t as exploded_datacite_id
  where
    datacite_ids is not null 
    and size(datacite_ids) > 0
),
-- Source lookup for repo: endpoint_id -> source (no staging table read needed)
repo_sources as (
  select
    *
  from
    existing_sources_for_repos
  where
    repo_row_number = 1
),
-- Source lookup for other_works via ISSN matching
-- Reads staging table ONCE, filtered to other_works provenances
other_works_source_lookup as (
  select
    native_id,
    id as source_id,
    is_oa_source
  from (
    select
      ow.native_id,
      esow.id,
      esow.is_oa_source,
      row_number() over (
        partition by ow.native_id
        order by
          case
            when rid.namespace = 'eissn' then 1
            when rid.namespace = 'lissn' then 2
            when rid.namespace = 'pissn' then 3
          end,
          rid.id
      ) as rn
    from (
      select
        native_id,
        explode_outer(
          filter(
            ids,
            x -> contains(x.namespace, 'issn')
            and (
              x.relationship in (
                'self',
                'IsVersionOf',
                'IsNewVersionOf',
                'IsPreviousVersionOf',
                'IsVariantFormOf',
                'IsOriginalFormOf',
                'IsIdentialTo',
                'IsTranslationOf',
                'HasTranslation'
              )
              or x.relationship is null
            )
          )
        ) as rid
      from identifier('openalex' || :env_suffix || '.works._lws_staging')
      where provenance not in ('repo', 'repo_backfill', 'datacite', 'pubmed')
    ) ow
    left join existing_sources_for_other_works esow
      on ow.rid.id = esow.issn
    where esow.id is not null
  )
  where rn = 1
),
-- Source lookup for datacite via datacite_client matching
-- Reads staging table ONCE, filtered to datacite provenance
datacite_source_lookup as (
  select
    native_id,
    source_id,
    is_oa_source
  from (
    select
      d.native_id,
      s.id as source_id,
      s.is_oa_source,
      row_number() over (
        partition by d.native_id
        order by s.id asc
      ) as rn
    from (
      select
        native_id,
        explode_outer(
          filter(
            ids,
            x -> x.namespace = 'datacite_client'
            and (x.relationship = 'self' or x.relationship is null)
          )
        ) as datacite_client_id
      from identifier('openalex' || :env_suffix || '.works._lws_staging')
      where provenance = 'datacite'
    ) d
    left join existing_sources_for_datacite s
      on d.datacite_client_id.id = s.datacite_id
  )
  where rn = 1 or (rn is null)
),
-- SINGLE pass through staging table, joining all source lookups
with_primary_source as (
  select
    al.provenance,
    al.native_id,
    al.native_id_namespace,
    al.title,
    al.normalized_title,
    al.authors,
    al.ids,
    al.raw_type,
    al.type,
    al.version,
    al.license,
    al.language,
    al.published_date,
    al.created_date,
    al.updated_date,
    al.issue,
    al.volume,
    al.first_page,
    al.last_page,
    al.is_retracted,
    al.abstract,
    al.source_name,
    al.publisher,
    al.funders,
    al.references,
    al.urls,
    al.mesh,
    al.is_oa,
    al.endpoint_id,
    al.abstract_inverted_index,
    al.authors_exist,
    al.affiliations_exist,
    al.is_corresponding_exists,
    al.best_doi,
    al.merge_key,
    al.pdf_url,
    al.landing_page_url,
    al.pdf_s3_id,
    al.grobid_s3_id,
    al.ingested_at,
    case
      when al.provenance = 'pubmed' then False
      when al.provenance in ('repo', 'repo_backfill') then rs.is_oa_source
      when al.provenance = 'datacite' then ds.is_oa_source
      else ows.is_oa_source
    end as is_oa_source,
    case
      when al.provenance = 'pubmed' then 4306525036
      when al.provenance in ('repo', 'repo_backfill') then rs.id
      when al.provenance = 'datacite' then ds.source_id
      else ows.source_id
    end as source_id
  from identifier('openalex' || :env_suffix || '.works._lws_staging') al
  left join repo_sources rs
    on al.provenance in ('repo', 'repo_backfill') and al.endpoint_id = rs.endpoint_id
  left join datacite_source_lookup ds
    on al.provenance = 'datacite' and al.native_id = ds.native_id
  left join other_works_source_lookup ows
    on al.provenance not in ('repo', 'repo_backfill', 'datacite', 'pubmed') and al.native_id = ows.native_id
),
-- Display name fallback
sources_unique_display_names as (
  select
    display_name,
    max(id) as id,
    max(is_oa) as is_oa_source,
    count(*) as rwcnt
  from
    openalex.sources.sources
  group by
    display_name
  having
    rwcnt = 1
),
with_display_name_fallback as (
  select
    u.provenance,
    u.native_id,
    u.native_id_namespace,
    u.title,
    u.normalized_title,
    u.authors,
    u.ids,
    u.raw_type,
    u.type,
    u.version,
    u.license,
    u.language,
    u.published_date,
    u.created_date,
    u.updated_date,
    u.issue,
    u.volume,
    u.first_page,
    u.last_page,
    u.is_retracted,
    u.abstract,
    u.source_name,
    u.publisher,
    u.funders,
    u.references,
    u.urls,
    u.mesh,
    u.is_oa,
    u.endpoint_id,
    u.abstract_inverted_index,
    u.authors_exist,
    u.affiliations_exist,
    u.is_corresponding_exists,
    u.best_doi,
    u.merge_key,
    u.pdf_url,
    u.landing_page_url,
    u.pdf_s3_id,
    u.grobid_s3_id,
    u.ingested_at,
    coalesce(u.is_oa_source, dn.is_oa_source) as is_oa_source,
    coalesce(u.source_id, dn.id) as source_id
  from
    with_primary_source u
    left join sources_unique_display_names dn
      on u.source_id is null and u.source_name = dn.display_name
),
-- Manual matching: single pass with cascading CASE
with_all_matching as (
  select * except(source_id),
    case
      when source_id is not null then source_id
      -- by url
      when REGEXP_EXTRACT(coalesce(landing_page_url, pdf_url), 'https?://(www\\.)?([^/]+)', 2) = 'europepmc.org' then 4306400806
      when REGEXP_EXTRACT(coalesce(landing_page_url, pdf_url), 'https?://(www\\.)?([^/]+)', 2) = 'ci.nii.ac.jp' then 4210197683
      when REGEXP_EXTRACT(coalesce(landing_page_url, pdf_url), 'https?://(www\\.)?([^/]+)', 2) = 'dialnet.unirioja.es' then 4306401293
      when REGEXP_EXTRACT(coalesce(landing_page_url, pdf_url), 'https?://(www\\.)?([^/]+)', 2) = 'osti.gov' then 4306402487
      when REGEXP_EXTRACT(coalesce(landing_page_url, pdf_url), 'https?://(www\\.)?([^/]+)', 2) = 'cqvip.com' then 4306500507
      when REGEXP_EXTRACT(coalesce(landing_page_url, pdf_url), 'https?://(www\\.)?([^/]+)', 2) = 'books.openedition.org' then 4210222637
      when REGEXP_EXTRACT(coalesce(landing_page_url, pdf_url), 'https?://(www\\.)?([^/]+)', 2) = 'cyberleninka.ru' then 4306401404
      when REGEXP_EXTRACT(coalesce(landing_page_url, pdf_url), 'https?://(www\\.)?([^/]+)', 2) = 'ntrs.nasa.gov' then 4306402118
      when REGEXP_EXTRACT(coalesce(landing_page_url, pdf_url), 'https?://(www\\.)?([^/]+)', 2) = 'scopus.com' then 4306400063
      when contains(coalesce(landing_page_url, pdf_url), 'hal.science') then 4306402512
      -- by doi prefix
      when best_doi like '10.20944/preprints%' then 6309402219
      when best_doi like '10.2139/ssrn.%' then 4210172589
      -- by publisher
      when LOWER(publisher) like '%research square platform%' then 4306402450
      when LOWER(publisher) like 'cold spring harbor laboratory%' then 4306402567
      else source_id
    end as source_id
  from with_display_name_fallback
)
select * from with_all_matching
);

-- %% [markdown]
-- ### Create and populate normalized columns

-- %%
ALTER TABLE identifier('openalex' || :env_suffix || '.works.locations_w_sources')
  ADD COLUMN normalized_source_name STRING AFTER source_name;

ALTER TABLE identifier('openalex' || :env_suffix || '.works.locations_w_sources')
  ADD COLUMN normalized_book_publisher STRING AFTER publisher;

UPDATE identifier('openalex' || :env_suffix || '.works.locations_w_sources')
  SET 
    normalized_source_name = LOWER(REGEXP_REPLACE(source_name, '[^\\p{L}\\p{N}]', '')),
    normalized_book_publisher = CASE 
      WHEN type IN ('book', 'book-chapter') AND publisher IS NOT NULL 
      THEN LOWER(REGEXP_REPLACE(publisher, '[^\\p{L}\\p{N}]', ''))
      ELSE NULL 
    END;

-- %% [markdown]
-- ### Match locations with type book and book-chapter using normalized publisher

-- %%
WITH ebook_platform_sources AS (
  SELECT
    id AS source_id,
    LOWER(REGEXP_REPLACE(publisher, '[^\\p{L}\\p{N}]', '')) AS normalized_publisher,
    COUNT(*) OVER (
      PARTITION BY LOWER(REGEXP_REPLACE(publisher, '[^\\p{L}\\p{N}]', ''))
    ) AS name_count
  FROM openalex.sources.sources
  WHERE type = 'ebook platform'
    AND publisher IS NOT NULL
  QUALIFY name_count = 1
)
MERGE INTO identifier('openalex' || :env_suffix || '.works.locations_w_sources') AS target
USING ebook_platform_sources AS source
ON target.source_id IS NULL
   AND target.normalized_book_publisher IS NOT NULL
   AND target.normalized_book_publisher = source.normalized_publisher
WHEN MATCHED THEN
  UPDATE SET target.source_id = source.source_id;

-- %% [markdown]
-- ### Match normalized source names to source display names as final fallback

-- %%
WITH final_display_name_fallback_sources AS ( -- get only unique titles (idea for later - check if it is non-numeric, length > N, more sources dedup coming)
  SELECT
    id AS source_id,
    LOWER(REGEXP_REPLACE(display_name, '[^\\p{L}\\p{N}]', '')) AS normalized_source_name,
    COUNT(*) OVER (
      PARTITION BY LOWER(REGEXP_REPLACE(display_name, '[^\\p{L}\\p{N}]', ''))
    ) AS name_count
  FROM openalex.sources.sources
  WHERE id NOT IN ( -- repetitive - integrate this whole things into overall SQL later
      4377196106, -- Internet Archive (Internet Archive)
      4306400349, -- CiteSeer X (The Pennsylvania State University)
      4308707206, -- Library Union Catalog of Bavaria, Berlin and Brandenburg (B3Kat Repository)
      4377196246, -- CISION
      4306400063, -- Scopus (Elsevier)
      7407052528, -- ResearchGate
      4306402117, -- Portail des Bibliotheques Municipales Specialisees (City of Paris)
      7407051242, -- E-Pics Bildarchiv
      7407051288, -- WSL Landesforstinventar
      4306400108  -- Library Stack (Library Stack)
    )  
  QUALIFY name_count = 1
)
MERGE INTO identifier('openalex' || :env_suffix || '.works.locations_w_sources') AS target
USING final_display_name_fallback_sources AS source
ON target.source_id IS NULL
   AND target.normalized_source_name = source.normalized_source_name
WHEN MATCHED THEN
  UPDATE SET target.source_id = source.source_id;

-- %%
-- Clean up staging table
DROP TABLE IF EXISTS identifier('openalex' || :env_suffix || '.works._lws_staging');

-- %%
SELECT * FROM identifier('openalex' || :env_suffix || '.works.locations_w_sources')
