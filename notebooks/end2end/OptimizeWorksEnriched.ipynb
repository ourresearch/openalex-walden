-- %% [markdown]
-- # Optimize Works Enriched
--
-- Compact files after all MERGEs in CreateWorksEnriched complete.
-- Table has liquid clustering on (id, updated_date), so OPTIMIZE reorganizes files accordingly.
-- This improves query performance for downstream jobs (ES sync, etc.).
--
-- Split out as a separate task so it can be skipped during testing.

-- %%
OPTIMIZE openalex.works.openalex_works
