# %%
# %python
# Serverless notebook control task; see DEV-RUNBOOK-r1.md (not SQL-warehouse compute).
import sys
from pathlib import Path
dbutils.widgets.text("artifact_root", "/Workspace/Users/rohan@openalex.org/stableid-r1")
ARTIFACT_ROOT = Path(dbutils.widgets.get("artifact_root"))
sys.path.insert(0, str(ARTIFACT_ROOT / "lib"))
from stable_award_ids import Release
from create_api import run
c = Release(spark, dbutils, "CreateAwardsAPI")

# %%
# %python
try:
    run(c)
    c.freeze_logs()
except Exception as exc:
    c.fail(exc)
    raise

# %%
# %python
# api_candidate is immutable version 0; hash/date calculation preceded the swap.
