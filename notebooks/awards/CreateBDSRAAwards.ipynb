# %% [markdown]
# # Create Batten Disease Support and Research Association Awards
#
# 8 BDGRI grant recipients (2025-26) from battenresearch.org; title+PI+institution+USD amount 100%. BDSRA Foundation funds via the Batten Disease Global Research Initiative (consortium). Dup AU row F4320331945.
#
# provenance `bdsra`, priority 345. F4320308508 (Path A).
#
# Source parquet: s3://openalex-ingest/awards/bdsra/bdsra_grants.parquet
# Built by scripts/local/bdsra_to_s3.py

# %% [markdown]
# ## Step 1: Create Staging Table from S3

# %%
# %sql
CREATE OR REPLACE TABLE openalex.awards.bdsra_raw
USING delta
AS
SELECT *, current_timestamp() as databricks_ingested_at
FROM parquet.`s3a://openalex-ingest/awards/bdsra/bdsra_grants.parquet`;

# %%
# %sql
SELECT COUNT(*) as total FROM openalex.awards.bdsra_raw;

# %%
# %sql
DESCRIBE openalex.awards.bdsra_raw;

# %%
# %sql
SELECT * FROM openalex.awards.bdsra_raw LIMIT 5;

# %% [markdown]
# ## Step 2: Create BDSRA Awards Table

# %%
# %sql
CREATE OR REPLACE TABLE openalex.awards.bdsra_awards
USING delta
AS
WITH
the_funder AS (
    SELECT funder_id, display_name, ror_id, doi
    FROM openalex.common.funder
    WHERE funder_id = 4320308508  -- Batten Disease Support and Research Association
),
awards_transformed AS (
    SELECT
        abs(xxhash64(CONCAT(f.funder_id, ':', LOWER(g.funder_award_id)))) % 9000000000 as id,
        g.title as display_name,
        CAST(NULL AS STRING) as description,
        f.funder_id,
        g.funder_award_id as funder_award_id,
        TRY_CAST(g.amount AS DECIMAL(18,2)) as amount,
        'USD' as currency,
        struct(
            CONCAT('https://openalex.org/F', f.funder_id) as id,
            f.display_name, f.ror_id, f.doi
        ) as funder,
        'grant' as funding_type,
        CAST(NULL AS STRING) as funder_scheme,
        'bdsra' as provenance,
        CASE WHEN TRY_CAST(g.start_year AS INT) IS NOT NULL THEN TRY_TO_DATE(CONCAT(TRY_CAST(g.start_year AS INT), '-01-01'), 'yyyy-MM-dd') END as start_date,
        CAST(NULL AS DATE) as end_date,
        TRY_CAST(g.start_year AS INT) as start_year,
        CAST(NULL AS INT) as end_year,
        CASE
            WHEN g.pi_family IS NOT NULL THEN
                struct(
                    g.pi_given as given_name,
                    g.pi_family as family_name,
                    CAST(NULL AS STRING) as orcid,
                    CAST(NULL AS DATE) as role_start,
                    struct(
                        g.institution as name,
                        CAST(NULL AS STRING) as country,
                        CAST(NULL AS ARRAY<STRUCT<id:STRING, type:STRING, asserted_by:STRING>>) as ids
                    ) as affiliation
                )
            ELSE NULL
        END as lead_investigator,
        CAST(NULL AS STRUCT<
            given_name:STRING, family_name:STRING, orcid:STRING, role_start:DATE,
            affiliation:STRUCT<name:STRING, country:STRING, ids:ARRAY<STRUCT<id:STRING, type:STRING, asserted_by:STRING>>>
        >) as co_lead_investigator,
        CAST(NULL AS ARRAY<STRUCT<
            given_name:STRING, family_name:STRING, orcid:STRING, role_start:DATE,
            affiliation:STRUCT<name:STRING, country:STRING, ids:ARRAY<STRUCT<id:STRING, type:STRING, asserted_by:STRING>>>
        >>) as investigators,
        g.landing_page_url as landing_page_url,
        CAST(NULL AS STRING) as doi,
        CAST(NULL AS STRING) as works_api_url,
        current_timestamp() as created_date,
        current_timestamp() as updated_date
    FROM openalex.awards.bdsra_raw g
    CROSS JOIN the_funder f
)
SELECT * FROM awards_transformed;

# %% [markdown]
# ## Step 3: Insert into openalex_awards_raw

# %%
# %sql
DELETE FROM openalex.awards.openalex_awards_raw
WHERE provenance = 'bdsra' AND priority = 345;

INSERT INTO openalex.awards.openalex_awards_raw
SELECT
    id, display_name, description, funder_id, funder_award_id, amount, currency,
    funder, funding_type, funder_scheme, provenance, start_date, end_date,
    start_year, end_year, lead_investigator, co_lead_investigator, investigators,
    landing_page_url, doi, works_api_url, created_date, updated_date,
    345 as priority
FROM openalex.awards.bdsra_awards;

# %% [markdown]
# ## Verification Queries

# %%
# %sql
SELECT COUNT(*) as total_awards FROM openalex.awards.bdsra_awards;

# %%
# %sql
SELECT id, display_name, funder_award_id, amount, currency, start_year FROM openalex.awards.bdsra_awards LIMIT 10;

# %%
# %sql
SELECT funder.display_name, COUNT(*) cnt FROM openalex.awards.bdsra_awards GROUP BY 1 ORDER BY cnt DESC;

# %%
# %sql
SELECT COUNT(*) total, COUNT(display_name) has_title, COUNT(amount) has_amount, COUNT(lead_investigator) has_pi,
  ROUND(try_divide(COUNT(amount),COUNT(*))*100,1) pct_amount FROM openalex.awards.bdsra_awards;

# %%
# %sql
-- Step 6.4a PI frequency
SELECT lead_investigator.given_name given, lead_investigator.family_name family, COUNT(*) n
FROM openalex.awards.bdsra_awards GROUP BY 1,2 ORDER BY n DESC LIMIT 20;

# %%
# %sql
SELECT lead_investigator.affiliation.name institution, COUNT(*) cnt FROM openalex.awards.bdsra_awards
WHERE lead_investigator.affiliation.name IS NOT NULL GROUP BY 1 ORDER BY cnt DESC LIMIT 20;

# %%
# %sql
SELECT COUNT(*) as bdsra_in_raw FROM openalex.awards.openalex_awards_raw WHERE provenance='bdsra' AND priority=345;
